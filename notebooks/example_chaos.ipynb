# %%
import sys
import os
from scipy.spatial import cKDTree

chemin_lib = os.path.abspath("..")

# Add path to Python path
sys.path.append(chemin_lib)

import pandas as pd

from sklearn.preprocessing import MultiLabelBinarizer
import torch
import numpy as np
import SimpleITK as sitk 

from metriclib.metric import StreamMetric, MetricResult, TabularMetric
from metriclib.report import Report

from metriclib.data import Dataset

# %%
### CHAOSDataset
    
class CHAOSDataset(Dataset):
    def __init__(self):
        base_dir = os.path.join("..", "sample-data", "CHAOS_dataset")
        df = pd.read_csv(os.path.join(base_dir, "CHAOS_metadatas.csv"))
        self.metadata = df
        self.metadata["CHAOS_ID"] = self.metadata["CHAOS_ID"].astype(int)
        self.labels = self.metadata["CHAOS_ID"]

    def __len__(self):
        return len(self.metadata.index)

    def __getitem__(self, index):
        metadata = self.metadata.iloc[index].to_dict()
        metadata["idx"] = int(index)
        num_id = str(self.metadata["CHAOS_ID"].iloc[index])
        record_path = os.path.join("..", "sample-data", "CHAOS_dataset", "img_NIFTI", "CHAOS_"+str(num_id)+".nii.gz") # Need to put the right files in the "img_NIFTI" folder
        
        if os.path.isfile(record_path):
            # x : mettre un seul tensor
            img = sitk.ReadImage(record_path)
            
            x = torch.tensor(sitk.GetArrayFromImage(img))
        else : 
            print("Input image file not found, initializing with x=1 .")
            x = 1 # to remplace with the "img_NIFTI" files
            
        
        seg1_path = os.path.join("..", "sample-data", "CHAOS_dataset", "seg_TotalSegmentator_NIFTI", "CHAOS_"+str(num_id)+".nii.gz")
        img_seg1 = sitk.ReadImage(seg1_path)
        seg1 = sitk.GetArrayFromImage(img_seg1)

        seg2_path = os.path.join("..", "sample-data", "CHAOS_dataset", "seg_nnInteractive_NIFTI", "CHAOS_"+str(num_id)+".nii.gz")
        img_seg2 = sitk.ReadImage(seg2_path)
        seg2 = sitk.GetArrayFromImage(img_seg2)

        y = torch.tensor([seg1, seg2])
                
        return x, y, metadata

dataset_chaos = CHAOSDataset()

# %%
report = Report(datasets=[dataset_chaos])
# mapping for columns in metadata file
dict_config = {'seg1_origin' : 'seg_nnInteractive_origin', 
               'seg1_spacing':'seg_nnInteractive_spacing', 
               'seg1_direction':'seg_nnInteractive_direction',
               'seg2_origin' : 'seg_TotalSegmentator_origin', 
               'seg2_spacing':'seg_TotalSegmentator_spacing', 
               'seg2_direction':'seg_TotalSegmentator_direction'}

report.add_metric("DICESimilarityCoefficient", metric_config=dict_config)
report.add_metric("IntersectionOverUnion", metric_config=dict_config)
report.add_metric("HausdorffDistance", metric_config=dict_config)
report.add_metric("HausdorffDistance95", metric_config=dict_config)
report.generate()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/tmp/ipykernel_2528602/2890442846.py:38: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   y = torch.tensor([seg1, seg2])
# 100%|██████████| 4/4 [01:25<00:00, 21.40s/it]
# ([{'metric': metriclib.metrics.measurement_process.DICESimilarityCoefficient,
#    'reference': None,
#    'metric_config': {'seg1_origin': 'seg_nnInteractive_origin',
#     'seg1_spacing': 'seg_nnInteractive_spacing',
#     'seg1_direction': 'seg_nnInteractive_direction',
#     'seg2_origin': 'seg_TotalSegmentator_origin',
#     'seg2_spacing': 'seg_TotalSegmentator_spacing',
#     'seg2_direction': 'seg_TotalSegmentator_direction'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='DICE', value=[0.9557618292959021, 0.954658851454453, 0.9496780735107732, 0.9502340455114242], cluster='Measurement Process', threshold=0.9, threshold_type='min')},
#   {'metric': metriclib.metrics.measurement_process.IntersectionOverUnion,
#    'reference': None,
#    'metric_config': {'seg1_origin': 'seg_nnInteractive_origin',
#     'seg1_spacing': 'seg_nnInteractive_spacing',
#     'seg1_direction': 'seg_nnInteractive_direction',
#     'seg2_origin': 'seg_TotalSegmentator_origin',
#     'seg2_spacing': 'seg_TotalSegmentator_spacing',
#     'seg2_direction': 'seg_TotalSegmentator_direction'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Intersection over Union Score between two segmentations', value=[0.9152718758130257, 0.9132510021084825, 0.9041780901262695, 0.9051865717767142], cluster='Measurement Process', threshold=0.85, threshold_type='min')},
#   {'metric': metriclib.metrics.measurement_process.HausdorffDistance,
#    'reference': None,
#    'metric_config': {'seg1_origin': 'seg_nnInteractive_origin',
#     'seg1_spacing': 'seg_nnInteractive_spacing',
#     'seg1_direction': 'seg_nnInteractive_direction',
#     'seg2_origin': 'seg_TotalSegmentator_origin',
#     'seg2_spacing': 'seg_TotalSegmentator_spacing',
#     'seg2_direction': 'seg_TotalSegmentator_direction'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='maximum Hausdorff Distance between two segmentations', value=[np.float32(2.183544), np.float32(4.6067276), np.float32(2.734375), np.float32(7.426932)], cluster='Measurement Process', threshold=5.0, threshold_type='max')},
#   {'metric': metriclib.metrics.measurement_process.HausdorffDistance95,
#    'reference': None,
#    'metric_config': {'seg1_origin': 'seg_nnInteractive_origin',
#     'seg1_spacing': 'seg_nnInteractive_spacing',
#     'seg1_direction': 'seg_nnInteractive_direction',
#     'seg2_origin': 'seg_TotalSegmentator_origin',
#     'seg2_spacing': 'seg_TotalSegmentator_spacing',
#     'seg2_direction': 'seg_TotalSegmentator_direction'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Hausdorff Distance 95% between two segmentations', value=[np.float32(0.7720032), np.float32(1.0), np.float32(1.0), np.float32(1.0)], cluster='Measurement Process', threshold=1.0, threshold_type='max')}],
#  [],
#  [{'Measurement Process': 1.0,
#    'Timeliness': 1.0,
#    'Representativeness': 1.0,
#    'Informativeness': 1.0,
#    'Consistency': 1.0}])

# %%
report = Report(datasets=[dataset_chaos])
dict_config = {'img_spacing':'img_spacing'}

report.add_metric("ImageEntropy3D")
report.add_metric("TotalPower_NoisePowerSpectrum_avg3D", metric_config=dict_config)
report.add_metric("Entropy_NoisePowerSpectrum_avg3D", metric_config=dict_config)
report.add_metric("ApproxTaskTransferFunction10", metric_config=dict_config)
report.add_metric("ApproxTaskTransferFunction50", metric_config=dict_config)
report.add_metric("MeanGradientMagnitudeScale")
report.generate()
# Out:
# 100%|██████████| 4/4 [01:59<00:00, 29.98s/it]
# ([{'metric': metriclib.metrics.measurement_process.ImageEntropy3D,
#    'reference': None,
#    'metric_config': None,
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Image entropy from a CT Scan image (NIFTI format)', value=np.float64(4.943750242658906), cluster=None, threshold=0, threshold_type='min')},
#   {'metric': metriclib.metrics.measurement_process.TotalPower_NoisePowerSpectrum_avg3D,
#    'reference': None,
#    'metric_config': {'img_spacing': 'img_spacing'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Total Power Noise Power Spectrum from a CT Scan image (NIFTI format)', value=[361.7797677689744, 2279.033290172574, 1286.092778288088, 596.409501096056], cluster='Measurement Process', threshold=0, threshold_type='min')},
#   {'metric': metriclib.metrics.measurement_process.Entropy_NoisePowerSpectrum_avg3D,
#    'reference': None,
#    'metric_config': {'img_spacing': 'img_spacing'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Noise Power Spectrum Entropy from a CT Scan image (NIFTI format)', value=[np.float64(0.6762902558980753), np.float64(3.1677474662866776), np.float64(3.628062389332241), np.float64(3.6427825305721173)], cluster='Measurement Process', threshold=0, threshold_type='min')},
#   {'metric': metriclib.metrics.measurement_process.ApproxTaskTransferFunction10,
#    'reference': None,
#    'metric_config': {'img_spacing': 'img_spacing'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Task Transfer Function 10 from a CT SCan image (NIFTI format)', value=[nan, nan, nan, nan], cluster='Measurement Process', threshold=0.08, threshold_type='min')},
#   {'metric': metriclib.metrics.measurement_process.ApproxTaskTransferFunction50,
#    'reference': None,
#    'metric_config': {'img_spacing': 'img_spacing'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Task Transfer Function 50 from a CT Scan image (NIFTI format)', value=np.float64(0.13150796834013628), cluster=None, threshold=0.15, threshold_type='min')},
#   {'metric': metriclib.metrics.measurement_process.MeanGradientMagnitudeScale,
#    'reference': None,
#    'metric_config': None,
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Mean Gradient Magnitude with Scales from a CT Scan image (NIFTI format)', value=[26.935062408447266, 25.44870376586914, 24.243668874104817, 19.439652760823567], cluster=None, threshold=0, threshold_type='min')}],
#  [],
#  [{'Measurement Process': 1.0,
#    'Timeliness': 1.0,
#    'Representativeness': 1.0,
#    'Informativeness': 1.0,
#    'Consistency': 1.0}])
