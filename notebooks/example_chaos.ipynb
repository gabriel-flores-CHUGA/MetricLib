# %%
import sys
import os
from scipy.spatial import cKDTree

chemin_lib = os.path.abspath("..")

# Add path to Python path
sys.path.append(chemin_lib)

import pandas as pd

from sklearn.preprocessing import MultiLabelBinarizer
import torch
import numpy as np
import SimpleITK as sitk 

from metriclib.metric import StreamMetric, MetricResult, TabularMetric
from metriclib.report import Report

from metriclib.data import Dataset

# %%
### CHAOSDataset
    
class CHAOSDataset(Dataset):
    def __init__(self):
        base_dir = os.path.join("..", "sample-data", "CHAOS_dataset")
        df = pd.read_csv(os.path.join(base_dir, "CHAOS_metadatas.csv"))
        self.metadata = df
        self.metadata["CHAOS_ID"] = self.metadata["CHAOS_ID"].astype(int)
        self.labels = self.metadata["CHAOS_ID"]

    def __len__(self):
        return len(self.metadata.index)

    def __getitem__(self, index):
        metadata = self.metadata.iloc[index].to_dict()
        metadata["idx"] = int(index)
        num_id = str(self.metadata["CHAOS_ID"].iloc[index])
        record_path = os.path.join("..", "sample-data", "CHAOS_dataset", "img_NIFTI", "CHAOS_"+str(num_id)+".nii.gz") # Need to put the right files in the "img_NIFTI" folder
        
        if os.path.isfile(record_path):
            # x : mettre un seul tensor
            img = sitk.ReadImage(record_path)
            
            x = torch.tensor(sitk.GetArrayFromImage(img))
        else : 
            print("Input image file not found, initializing with x=1 .")
            x = 1 # to remplace with the "img_NIFTI" files
            
        
        seg1_path = os.path.join("..", "sample-data", "CHAOS_dataset", "seg_TotalSegmentator_NIFTI", "CHAOS_"+str(num_id)+".nii.gz")
        img_seg1 = sitk.ReadImage(seg1_path)
        seg1 = sitk.GetArrayFromImage(img_seg1)

        seg2_path = os.path.join("..", "sample-data", "CHAOS_dataset", "seg_nnInteractive_NIFTI", "CHAOS_"+str(num_id)+".nii.gz")
        img_seg2 = sitk.ReadImage(seg2_path)
        seg2 = sitk.GetArrayFromImage(img_seg2)

        y = torch.tensor([seg1, seg2])
                
        return x, y, metadata

dataset_chaos = CHAOSDataset()

# %%
report = Report(datasets=[dataset_chaos])
# mapping for columns in metadata file
dict_config = {'seg1_origin' : 'seg_nnInteractive_origin', 
               'seg1_spacing':'seg_nnInteractive_spacing', 
               'seg1_direction':'seg_nnInteractive_direction',
               'seg2_origin' : 'seg_TotalSegmentator_origin', 
               'seg2_spacing':'seg_TotalSegmentator_spacing', 
               'seg2_direction':'seg_TotalSegmentator_direction'}

report.add_metric("DICESimilarityCoefficient", metric_config=dict_config)
report.add_metric("IntersectionOverUnion", metric_config=dict_config)
report.add_metric("HausdorffDistance", metric_config=dict_config)
report.add_metric("HausdorffDistance95", metric_config=dict_config)
report.generate()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/tmp/ipykernel_1020027/2890442846.py:38: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   y = torch.tensor([seg1, seg2])
# 100%|██████████| 4/4 [01:24<00:00, 21.04s/it]
# ([{'metric': metriclib.metrics.measurement_process.DICESimilarityCoefficient,
#    'reference': None,
#    'metric_config': {'seg1_origin': 'seg_nnInteractive_origin',
#     'seg1_spacing': 'seg_nnInteractive_spacing',
#     'seg1_direction': 'seg_nnInteractive_direction',
#     'seg2_origin': 'seg_TotalSegmentator_origin',
#     'seg2_spacing': 'seg_TotalSegmentator_spacing',
#     'seg2_direction': 'seg_TotalSegmentator_direction'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='DICE Score between two segmentations', value=[0.9557618292959021, 0.954658851454453, 0.9496780735107732, 0.9502340455114242], cluster='Measurement Process', threshold=0)},
#   {'metric': metriclib.metrics.measurement_process.IntersectionOverUnion,
#    'reference': None,
#    'metric_config': {'seg1_origin': 'seg_nnInteractive_origin',
#     'seg1_spacing': 'seg_nnInteractive_spacing',
#     'seg1_direction': 'seg_nnInteractive_direction',
#     'seg2_origin': 'seg_TotalSegmentator_origin',
#     'seg2_spacing': 'seg_TotalSegmentator_spacing',
#     'seg2_direction': 'seg_TotalSegmentator_direction'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Intersection over Union Score between two segmentations', value=[0.9152718758130257, 0.9132510021084825, 0.9041780901262695, 0.9051865717767142], cluster=None, threshold=0)},
#   {'metric': metriclib.metrics.measurement_process.HausdorffDistance,
#    'reference': None,
#    'metric_config': {'seg1_origin': 'seg_nnInteractive_origin',
#     'seg1_spacing': 'seg_nnInteractive_spacing',
#     'seg1_direction': 'seg_nnInteractive_direction',
#     'seg2_origin': 'seg_TotalSegmentator_origin',
#     'seg2_spacing': 'seg_TotalSegmentator_spacing',
#     'seg2_direction': 'seg_TotalSegmentator_direction'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='maximum Hausdorff Distance between two segmentations', value=[np.float32(2.183544), np.float32(4.6067276), np.float32(2.734375), np.float32(7.426932)], cluster=None, threshold=0)},
#   {'metric': metriclib.metrics.measurement_process.HausdorffDistance95,
#    'reference': None,
#    'metric_config': {'seg1_origin': 'seg_nnInteractive_origin',
#     'seg1_spacing': 'seg_nnInteractive_spacing',
#     'seg1_direction': 'seg_nnInteractive_direction',
#     'seg2_origin': 'seg_TotalSegmentator_origin',
#     'seg2_spacing': 'seg_TotalSegmentator_spacing',
#     'seg2_direction': 'seg_TotalSegmentator_direction'},
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Hausdorff Distance 95% \x08etween two segmentations', value=[np.float32(0.7720032), np.float32(1.0), np.float32(1.0), np.float32(1.0)], cluster=None, threshold=0)}],
#  [],
#  [{'Measurement Process': 1.0,
#    'Timeliness': 1.0,
#    'Representativeness': 1.0,
#    'Informativeness': 1.0,
#    'Consistency': 1.0}])

# %%
report = Report(datasets=[dataset_chaos])
report.add_metric("ImageEntropy")
report.add_metric("NoisePowerSpectrum")
report.add_metric("TaskTransferFunction10")
report.add_metric("TaskTransferFunction50")
report.add_metric("MeanGradientMagnitudeScale")
report.generate()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# In function MIN/MAX: -2048.0 10318.0
# VAR patch mean: 15.971381
#  25%|██▌       | 1/4 [00:20<01:02, 20.79s/it]
# In function MIN/MAX: -1024.0 1422.0
# VAR patch mean: 55.886513
#  50%|█████     | 2/4 [00:46<00:47, 23.74s/it]
# In function MIN/MAX: -1024.0 1303.0
# VAR patch mean: 39.221367
#  75%|███████▌  | 3/4 [01:11<00:24, 24.24s/it]
# In function MIN/MAX: -1024.0 1540.0
# VAR patch mean: 18.58657
# 100%|██████████| 4/4 [01:34<00:00, 23.52s/it]
# ([{'metric': metriclib.metrics.measurement_process.ImageEntropy,
#    'reference': None,
#    'metric_config': None,
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Image entropy from a CT Scan image (NIFTI format)', value=[4.378446502979831, 5.223950600118041, 5.788077442710999, 5.0265379063251725], cluster=None, threshold=0)},
#   {'metric': metriclib.metrics.measurement_process.NoisePowerSpectrum,
#    'reference': None,
#    'metric_config': None,
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Noise Power Spectrum from a CT Scan image (NIFTI format)', value=[(array([2.00597229, 4.35941638, 6.213901  , 7.8151799 , 8.03050101,
#           6.6375147 , 6.45730516, 4.86741418, 3.700945  , 3.02509008,
#           2.11126249, 1.46634969, 0.99364838, 0.74771181, 0.51348854,
#           0.41769621, 0.39076426, 0.22221529, 0.11125773, 0.06549764,
#           0.03773292, 0.030518  , 0.03089534]), array([0.     , 0.03125, 0.0625 , 0.09375, 0.125  , 0.15625, 0.1875 ,
#           0.21875, 0.25   , 0.28125, 0.3125 , 0.34375, 0.375  , 0.40625,
#           0.4375 , 0.46875, 0.5    , 0.53125, 0.5625 , 0.59375, 0.625  ,
#           0.65625, 0.6875 ]), {'num_total_patches': 900, 'num_selected_patches': 90, 'total_power': 60.25227800365219, 'mean_frequency': 0.16746485150980692, 'peak_frequency': 0.125, 'noise_type': 'high_frequency', 'mean_score_selected': 9.81583023071289}), (array([19.13981479, 25.90336322, 25.10909592, 26.05137298, 24.1978937 ,
#           25.4521714 , 20.23790217, 18.13586928, 13.03604679, 10.36372849,
#            8.34847388,  5.76554152,  4.51908668,  2.43706158,  1.6958354 ,
#            1.00999335,  0.53336513,  0.25534212,  0.12912877,  0.07845201,
#            0.0731673 ,  0.08632546,  0.10047633]), array([0.     , 0.03125, 0.0625 , 0.09375, 0.125  , 0.15625, 0.1875 ,
#           0.21875, 0.25   , 0.28125, 0.3125 , 0.34375, 0.375  , 0.40625,
#           0.4375 , 0.46875, 0.5    , 0.53125, 0.5625 , 0.59375, 0.625  ,
#           0.65625, 0.6875 ]), {'num_total_patches': 900, 'num_selected_patches': 90, 'total_power': 232.65950826065085, 'mean_frequency': 0.15018633061710226, 'peak_frequency': 0.09375, 'noise_type': 'high_frequency', 'mean_score_selected': 34.59628677368164}), (array([17.81584829, 21.63191611, 20.67993884, 19.60730999, 20.00214679,
#           19.77533764, 14.86250937, 13.00293199,  8.65586939,  6.05313425,
#            4.965318  ,  3.23761358,  2.35937888,  1.4004711 ,  0.81451486,
#            0.42342981,  0.22978829,  0.14144128,  0.11557272,  0.10178387,
#            0.09829625,  0.08262543,  0.04402843]), array([0.     , 0.03125, 0.0625 , 0.09375, 0.125  , 0.15625, 0.1875 ,
#           0.21875, 0.25   , 0.28125, 0.3125 , 0.34375, 0.375  , 0.40625,
#           0.4375 , 0.46875, 0.5    , 0.53125, 0.5625 , 0.59375, 0.625  ,
#           0.65625, 0.6875 ]), {'num_total_patches': 900, 'num_selected_patches': 90, 'total_power': 176.1012051632264, 'mean_frequency': 0.13644941391801693, 'peak_frequency': 0.03125, 'noise_type': 'low_frequency', 'mean_score_selected': 25.026269912719727}), (array([3.74193579, 6.42198998, 8.05328002, 8.49853469, 8.60464061,
#           9.56028857, 8.99769562, 6.37150535, 4.2237281 , 3.11712478,
#           2.35696361, 1.76356425, 1.18695488, 0.62897559, 0.35951543,
#           0.1776098 , 0.097259  , 0.05154763, 0.03666412, 0.03365592,
#           0.03698906, 0.03948518, 0.03626747]), array([0.     , 0.03125, 0.0625 , 0.09375, 0.125  , 0.15625, 0.1875 ,
#           0.21875, 0.25   , 0.28125, 0.3125 , 0.34375, 0.375  , 0.40625,
#           0.4375 , 0.46875, 0.5    , 0.53125, 0.5625 , 0.59375, 0.625  ,
#           0.65625, 0.6875 ]), {'num_total_patches': 900, 'num_selected_patches': 90, 'total_power': 74.3961754357204, 'mean_frequency': 0.1553590825218155, 'peak_frequency': 0.15625, 'noise_type': 'high_frequency', 'mean_score_selected': 13.05535888671875})], cluster=None, threshold=0)},
#   {'metric': metriclib.metrics.measurement_process.TaskTransferFunction10,
#    'reference': None,
#    'metric_config': None,
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Task Transfer Function 10 from a CT SCan image (NIFTI format)', value=[nan, nan, nan, nan], cluster=None, threshold=0)},
#   {'metric': metriclib.metrics.measurement_process.TaskTransferFunction50,
#    'reference': None,
#    'metric_config': None,
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Task Transfer Function 50 from a CT Scan image (NIFTI format)', value=[np.float64(0.5634179688238729), np.float64(0.3190772884765946), np.float64(0.31467450785919676), np.float64(0.35880050707813615)], cluster=None, threshold=0)},
#   {'metric': metriclib.metrics.measurement_process.MeanGradientMagnitudeScale,
#    'reference': None,
#    'metric_config': None,
#    'dataset': 'CHAOSDataset',
#    'name': None,
#    'result': MetricResult(description='Mean Gradient Magnitude with Scales from a CT Scan image (NIFTI format)', value=[22.30713144938151, 20.692845662434895, 22.595654169718426, 15.93309211730957], cluster=None, threshold=0)}],
#  [],
#  [{'Measurement Process': 1.0,
#    'Timeliness': 1.0,
#    'Representativeness': 1.0,
#    'Informativeness': 1.0,
#    'Consistency': 1.0}])
